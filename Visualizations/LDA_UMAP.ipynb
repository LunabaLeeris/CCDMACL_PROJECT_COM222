# %%
import pandas as pd
import re
from sklearn.decomposition import LatentDirichletAllocation as LDA
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.preprocessing import StandardScaler

# %%
import torch
import torch_directml  # Correct way to use DirectML with PyTorch

# Initialize DirectML device
device = torch_directml.device()
print(f"Using device: {device}")

# Test tensor on GPU
tensor = torch.ones(5, device=device)
print(tensor)
# Out:
# Using device: privateuseone:0
# tensor([1., 1., 1., 1., 1.], device='privateuseone:0')

# %%
# Load the data
drive_path = "C:/ML/separated_postings.csv"
df = pd.read_csv(drive_path, engine="python", on_bad_lines='skip')

# %%
# Preprocess the text data
def preprocess(text):
    text = re.sub(r'\W+', ' ', str(text).lower())  # Remove special characters and lowercase
    return text

# %%
df['clean_text'] = df.iloc[:, 0].dropna().apply(preprocess)  # Assuming job postings are in the first column
vectorizer = CountVectorizer(max_df=0.9, min_df=10, stop_words='english')
text_matrix = vectorizer.fit_transform(df['clean_text'].dropna())

# %%
# Fit LDA model
num_topics = 10  # Adjust based on your data
lda_model = LDA(n_components=num_topics, random_state=42)
lda_matrix = lda_model.fit_transform(text_matrix)

# %%
# Display the topics with top words
def display_topics(model, feature_names, num_top_words=100):
    for topic_idx, topic in enumerate(model.components_):
        print(f"\nTopic {topic_idx + 1}:")
        print(" ".join([feature_names[i] for i in topic.argsort()[-num_top_words:]]))

# %%
display_topics(lda_model, vectorizer.get_feature_names_out())
# Out:
# Topic 1:
# technology executive provide career looking driven formatted_experience_level leadership zip_code passion manage brands self fast learn day excellent learning selling world grow results speciality strategies client join business_development building strategy ensure responsibilities vision paid lead events com clients years culture performance training needs help job full_time key service make social based benefits working creative position goals store teams develop account best ll high opportunity level support build create digital content people communication management drive relationships success retail products development brand market environment media manager opportunities strong including growth customers ability role product company new skills business customer work marketing team sales
#
# Topic 2:
# account value full_time program impact offer build required identity color bank related programs level internal degree applicable ll service veteran origin religion compliance employer pay senior environment sexual market orientation race diversity medical knowledge employee make health plan culture salary relationships best tax banking sales equal applicants needs financial_services years working finance career paid national position protected provide products customer global information development strong help opportunities process customers compensation employment gender people based risk range com solutions opportunity employees disability job services life ability new management company status support client role including skills insurance clients benefits team work financial business
#
# Topic 3:
# high make range service comprehensive year plans dental procedures rehabilitation day information provider join opportunities ability unit families mission working qualifications years physicians formatted_experience_level position facility employer appropriate members medicine licensed environment paid providing speciality pay new insurance com certified full_time assistant career training therapy requirements license shift provides skills status plan opportunity physician needs based zip_code current preferred professional offsite home posting_domain physical level treatment certification community including family program provide state health_care_provider education support center registered practice benefits rn life quality job staff required hospital work team services nurse hospitals_and_health_care clinical nursing healthcare medical patients patient health care
#
# Topic 4:
# developing collaborate remote agile problem issues required position expertise lead communication cyber process practices processes qualifications architecture engineers enterprise code platform quality functional com responsibilities mid automation provide best sql projects analysis full_time end zip_code opportunity information computer based power company project degree user job science environment performance formatted_experience_level integration develop understanding network application infrastructure onsite related speciality test contract using new management testing applications ability strong it_services_and_it_consulting including working tools role product requirements information_technology teams senior technologies complex services knowledge level cloud support years engineer technology skills business security team solutions development software work systems technical design engineering data
#
# Topic 5:
# using 50 hands complete status equal order clean opportunity area operating tasks entry employment qualifications performing pounds warehouse lbs technical include occasionally material related safe needed conditions basic technician speciality plant repair inventory industrial operations formatted_experience_level shift posting_domain years offsite employees tools vision preferred control lift process functions responsible full_time assigned parts materials engineering standards com training zip_code ensure essential employee physical working high mechanical maintain procedures responsibilities use electrical food product systems team management products customers including level knowledge service position customer requirements able environment production duties skills perform company quality maintenance job manufacturing required safety ability equipment work
#
# Topic 6:
# services accountant software attention specialist follow finance type monthly assists day years working systems laboratory excel strong education review qualifications provide prepare microsoft calls documents accuracy performs documentation requests issues policies process maintains speciality manner company requirements formatted_experience_level daily written billing team equipment full_time able necessary essential assistant payroll excellent zip_code processing general computer records accurate tasks appropriate data department support related responsible ensure environment entry communication staff financial timely level assigned reports functions high needed preferred accounts including insurance maintain perform assist job responsibilities knowledge medical customer position administrative information procedures service duties office ability required work skills accounting
#
# Topic 7:
# hiring meet medical accommodation office new local activities use assistance compensation knowledge insurance paid contact government plan offsite human additional duties sex candidates pay eligible religion working policy range minimum management learning veteran non identity student orientation race include color skills salary development origin age sexual public degree applicable ability security service individuals qualified protected years department professional staff employer research year community employee level based university law gender school equal related provide students health qualifications opportunity programs national services support disability requirements training application benefits federal including applicants employees job state required status program education information employment position work
#
# Topic 8:
# multiple relationships contract engineering speciality goals systems hr technical plan operational budget standards external initiatives onsite effective programs practices job training organizational stakeholders resources ensuring cost staff program working strategic organization position managing effectively review identify environment improvement full_time key issues excellent new level maintain client field office director bachelors role responsible plans reporting preferred lead teams activities provide complex internal reports analysis responsibilities requirements quality financial processes data required company performance process develop knowledge leadership communication degree compliance planning senior years operations construction strong related manage including support development ensure manager projects ability business work team skills project management
#
# Topic 9:
# guest needs pet sex qualifications eligible programs need care offer hospitality requirements manager applicants able include speciality entry working type family term state associate religion products ll based merchandise veteran origin identity physical color formatted_experience_level orientation high flexible race sexual holidays opportunities plan hours provide national zip_code skills local environment people protected duties age health management training associates assistance required sales offsite information vision services position posting_domain dental level gender day program equal employer medical career employees ability life com pay 401 opportunity status employment including employee disability job insurance team retail paid customers customer store benefits service company work
#
# Topic 10:
# based simple en www recruiter details ca attorney health requirements provide life bonus plus remote required including executive vision posting_domain responsibilities candidate hours professional litigation administrative opportunities employment competitive qualifications week recruitment hourly med office weekly group role strong resume accounting salary network candidates cogent paid excellent associate support new pro medical mid law seeking yearly looking join dental pay company recruiting opportunity skills complex position career senior com firm level team min_salary max_salary healthcare 401 years type client full_time usd currency travel normalized_salary pay_period compensation_type base_salary clients zip_code formatted_experience_level work legal job insurance benefits speciality onsite contract staffing staffing_and_recruiting

# %%
import umap

# Apply UMAP for dimensionality reduction
umap_reducer = umap.UMAP(random_state=42)
lda_umap = umap_reducer.fit_transform(lda_matrix)  # Renamed variable
# Out:
# C:\Users\nicole\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\nicole\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# C:\Users\nicole\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\umap\spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(

# %%
dominant_topics = lda_matrix.argmax(axis=1)

# %%
feature_names = vectorizer.get_feature_names_out()

# %%
word_topic_assignments = lda_model.components_.argmax(axis=0)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
import colorsys

# %%
topic_colors = cm.get_cmap('tab10', num_topics)  # Adjust based on number of topics
# Out:
# C:\Users\nicole\AppData\Local\Temp\ipykernel_12952\4227479930.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   topic_colors = cm.get_cmap('tab10', num_topics)  # Adjust based on number of topics

# %%
# Function to lighten colors for better readability
def lighten_color(rgb_color, factor=1.6):
    """Lightens an RGB color for better contrast."""
    h, l, s = colorsys.rgb_to_hls(*rgb_color[:3])
    l = min(1, l * factor)
    return colorsys.hls_to_rgb(h, l, s)

# %%
# Compute centroids properly
topic_centroids = {}
for topic_id in range(num_topics):
    topic_points = lda_umap[dominant_topics == topic_id]  # Ensure matching shapes
    if len(topic_points) > 0:
        centroid = topic_points.mean(axis=0)
    else:
        centroid = np.array([0, 0])  # Avoids indexing issues
    topic_centroids[topic_id] = centroid

# %%
# Updated annotation function with outline and larger text
def annotate_words_lda(word_list, feature_names, lda_model, topic_centroids):
    for word in word_list:
        if word in feature_names:
            word_idx = np.where(feature_names == word)[0][0]
            dominant_topic = word_topic_assignments[word_idx]
            x, y = topic_centroids.get(dominant_topic, (0, 0))

            # Get original topic color and lighten it
            original_color = topic_colors(dominant_topic)[:3]
            lightened_color = lighten_color(original_color, factor=1.5)

            # Add annotation with outline (shadow effect)
            plt.text(
                x, y, word,
                fontsize=14,  # Larger font
        
            )

# %%
import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects

# Create a single plot with a reduced figure size for VSCode output cell
fig, ax = plt.subplots(figsize=(12, 8))
fig.suptitle('UMAP Visualization of LDA Topics with Selected Word Annotations', fontsize=16)

# Scatter plot with topic colors
scatter = ax.scatter(
    lda_umap[:, 0], 
    lda_umap[:, 1], 
    c=dominant_topics, 
    cmap='tab10', 
    s=8, 
    alpha=0.6
)

selected_words = [
    # Tech & Programming
    'python', 'java', 'javascript', 'c++', 'html', 'css', 'react', 'angular', 'node',
    'backend', 'frontend', 'machine', 'learning', 'data', 'cloud', 'aws', 'docker',
    'devops', 'database', 'sql', 'nosql', 'api', 'tensorflow', 'pytorch', 'nlp', 'ai',
    'robotics', 'cybersecurity', 'blockchain',

    # Medicine & Healthcare
    'doctor', 'nurse', 'hospital', 'pharmacy', 'surgeon', 'treatment', 'diagnosis',
    'vaccine', 'covid', 'disease', 'therapy', 'biotech', 'gene', 'neuroscience',
    'cardiology', 'radiology', 'oncology', 'anatomy', 'dentist', 'psychology',
    'mental', 'health', 'nursing', 'pharmaceutical', 'medication', 'biology',
    'biochemistry',

    # Finance & Business
    'banking', 'investment', 'stocks', 'trading', 'bitcoin', 'crypto', 'insurance',
    'loan', 'mortgage', 'accounting', 'audit', 'financial', 'tax', 'economics',
    'revenue', 'profit', 'loss', 'funding', 'venture', 'capital', 'fintech', 'payroll',
    'dividends', 'budget', 'credit', 'debt', 'interest', 'exchange',

    # Engineering & Manufacturing
    'mechanical', 'electrical', 'civil', 'aerospace', 'automotive', 'robotics',
    'circuit', 'design', 'blueprint', 'CAD', 'manufacturing', 'production',
    'materials', 'welding', 'construction', 'structural', 'infrastructure', 'thermal',
    'hydraulics', 'renewable', 'energy', 'nanotechnology', 'automation', 'assembly',
    'fabrication',

    # Education & Research
    'university', 'professor', 'research', 'academic', 'study', 'publication',
    'dissertation', 'mathematics', 'physics', 'chemistry', 'biology', 'history',
    'philosophy', 'sociology', 'linguistics', 'pedagogy', 'learning', 'teacher',
    'classroom', 'curriculum', 'literature', 'thesis',

    # Marketing & Advertising
    'brand', 'social', 'media', 'advertising', 'seo', 'digital', 'campaign', 'content',
    'strategy', 'promotion', 'ecommerce', 'copywriting', 'conversion', 'metrics',
    'branding', 'sales', 'consumer', 'analytics', 'PR', 'engagement', 'funnel', 'viral',
    'influencer', 'targeting',

    # Legal & Compliance
    'lawyer', 'court', 'legal', 'contract', 'regulation', 'policy', 'compliance',
    'ethics', 'litigation', 'intellectual', 'property', 'corporate', 'patent',
    'trademark', 'criminal', 'civil', 'human', 'rights', 'attorney', 'defendant',
    'plaintiff',

    # Logistics & Supply Chain
    'logistics', 'supply', 'warehouse', 'inventory', 'distribution', 'transportation',
    'freight', 'shipping', 'retail', 'wholesale', 'procurement', 'packaging', 'global',
    'sourcing', 'costing', 'demand', 'forecasting', 'delivery', 'fleet', 'automation',

    # Human Resources & Recruitment
    'recruitment', 'hiring', 'interview', 'resume', 'job', 'career', 'employee',
    'employer', 'hr', 'training', 'leadership', 'workplace', 'team', 'benefits',
    'onboarding', 'performance', 'motivation', 'skills', 'diversity', 'culture',

    # Customer Support & Service
    'customer', 'support', 'service', 'complaint', 'resolution', 'satisfaction', 'call',
    'email', 'chat', 'feedback', 'quality', 'assurance', 'helpdesk', 'response', 'crm',
    'loyalty', 'issue', 'ticket', 'escalation',

    # General & Miscellaneous
    'remote', 'hybrid', 'full-time', 'part-time', 'internship', 'freelance', 'consultant',
    'gig', 'startup', 'corporate', 'industry', 'trend', 'innovation', 'growth', 'future',
    'success', 'challenge', 'opportunity', 'networking'
]


# Annotate only the selected words
for word in selected_words:
    if word in vectorizer.vocabulary_:
        idx = vectorizer.vocabulary_[word]
        x, y = lda_umap[idx]
        txt = ax.text(x, y, word, fontsize=8, weight='bold', color='black')
        txt.set_path_effects([
            path_effects.Stroke(linewidth=1.5, foreground='white'), 
            path_effects.Normal()
        ])

# Labels and layout
ax.set_xlabel('UMAP Component 1', fontsize=10)
ax.set_ylabel('UMAP Component 2', fontsize=10)

# Colorbar with smaller size for VSCode
cbar = plt.colorbar(scatter, ax=ax, label='Topic ID', fraction=0.02, pad=0.02)
cbar.ax.tick_params(labelsize=8)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
